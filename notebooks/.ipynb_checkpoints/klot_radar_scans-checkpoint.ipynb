# %%
######################
# Jason Hemedinger
# Argonne National Laboratory
# This notebook will pull radar data from Amazon S3

# %%
import pyart
import boto3
import tempfile
import pytz
import cartopy
import matplotlib.pyplot as plt
from datetime import datetime
from botocore.handlers import disable_signing
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
#creating a bucket name. This bucket is where all the nexrad data is located.
bucket = 'noaa-nexrad-level2'

#To get the data we also need to create a client. In this case the client is the S3 server
s3 = boto3.resource('s3')

#setting the data to unsigned
s3.meta.client.meta.events.register('choose-signer.s3.*', disable_signing)

# %%
#we can now connect the bucket with the radar data
aws_radar = s3.Bucket(bucket)

# %%
#indexing the data to only get data for the current day
for obj in aws_radar.objects.filter(Prefix='2018/06/04/KLOT'):
    print('{0}:{1}'.format(aws_radar.name, obj.key))
# Out:
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_000903_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_001850_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_002836_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_003823_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_004809_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_005754_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_010741_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_011727_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_012713_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_013700_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_014646_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_015633_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_020619_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_021606_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_022552_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_023539_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_024525_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_025511_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_030458_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_031444_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_032431_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_033417_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_034404_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_035350_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_040336_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_041323_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_042309_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_043523_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_044510_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_045456_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_050443_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_051429_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_052416_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_053401_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_054348_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_055334_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_060321_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_061308_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_062254_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_063241_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_064227_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_065214_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_070200_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_071147_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_072134_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_073120_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_074106_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_075053_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_080039_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_081025_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_082011_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_082958_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_083943_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_084930_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_085916_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_090903_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_091850_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_092836_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_093823_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_094809_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_095756_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_100742_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_101729_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_102716_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_103702_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_104649_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_105635_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_110622_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_111608_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_112555_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_113542_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_114528_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_115514_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_120501_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_121447_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_122433_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_151510_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_152005_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_152501_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_152958_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_153454_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_153950_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_154447_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_154943_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_155439_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_155936_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_160432_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_173958_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_174453_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_175015_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_180001_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_180948_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_181934_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_182921_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_183907_V06
# noaa-nexrad-level2:2018/06/04/KLOT/KLOT20180604_184854_V06

# %%
my_list_of_keys = [this_object.key for this_object in aws_radar.objects.filter(Prefix='2018/06/04/KLOT/')]
print(my_list_of_keys[1])
# Out:
# 2018/06/04/KLOT/KLOT20180604_001850_V06

# %%
my_datetime = datetime.strptime(my_list_of_keys[1][20:35], '%Y%m%d_%H%M%S')
print(my_datetime)

my_list_of_datetimes = []

for obj in aws_radar.objects.filter(Prefix='2018/06/04/KLOT'):
    try:
        my_list_of_datetimes.append(datetime.strptime(obj.key[20:35], '%Y%m%d_%H%M%S'))
    except Valueerror:
        pass
# Out:
# 2018-06-04 00:18:50

# %%
def nearest(items, pivot):
    return min(items, key=lambda x: abs(x-pivot))

# %%
desired_time = datetime(2018,6,4,12,0)

my_nearest = nearest(my_list_of_datetimes, desired_time)

print('nearest: ', my_nearest, 'desired: ', desired_time)

print('index: ', my_list_of_datetimes.index(my_nearest))

print('key: ', my_list_of_keys[my_list_of_datetimes.index(my_nearest)])
# Out:
# nearest:  2018-06-04 11:55:14 desired:  2018-06-04 12:00:00
# index:  72
# key:  2018/06/04/KLOT/KLOT20180604_115514_V06

# %%
def find_my_key(radar_name, desired_datetime):
    """
    Find the key in Amazon s3 corresponding to a particular radar site and 
    datetime
    
    Parameters
    ----------
    radar_name : str
        Four letter radar name
    desired_datetime : datetime
        The date time desired
    Returns
    -------
    my_key : string
        string matching the key for the radar file on AWS s3
    """
    
    bucket = "noaa-nexrad-level2"
    # Create a s3 "client"
    s3 = boto3.resource('s3')
    # Set it to unsigned 
    s3.meta.client.meta.events.register('choose-signer.s3.*', disable_signing)
    target_string = datetime.strftime(desired_datetime, '%Y/%m/%d/'+radar_name)
    my_list_of_keys = [this_object.key for this_object in aws_radar.objects.filter(Prefix=target_string)]
    my_list_of_datetimes = []
    for obj in aws_radar.objects.filter(Prefix=target_string):
        try:
            my_list_of_datetimes.append(datetime.strptime(obj.key[20:35], '%Y%m%d_%H%M%S'))
        except ValueError:
            pass #usually a tar file left in the bucket
    my_nearest = nearest(my_list_of_datetimes, desired_datetime)
    my_key = my_list_of_keys[my_list_of_datetimes.index(my_nearest)]
    return my_key

# %%
print(find_my_key('KLOT', datetime(2011,1,1,20,15)))
print(find_my_key('KILX', datetime.utcnow()))
print(find_my_key('TJUA', datetime(2017,9,20,9,0)))
# Out:
# 2011/01/01/KLOT/KLOT20110101_201844_V03.gz
# 2018/06/04/KILX/KILX20180604_190625_V06
# 2017/09/20/TJUA/TJUA20170920_085854_V06

# %%
steph_time= datetime(2018,5,30,17,59)
my_key = find_my_key('KIND', steph_time)
print(my_key)

localfile = tempfile.NamedTemporaryFile()

aws_radar.download_file(my_key, localfile.name)

radar= pyart.io.read(localfile.name)
# Out:
# 2018/05/30/KIND/KIND20180530_175953_V06

# %%
#Sweep we want to plot
sweep = 0

#Get the date at the start of collection
index_at_start = radar.sweep_start_ray_index['data'][sweep]
time_at_start_of_radar = pyart.io.cfradial.netCDF4.num2date(radar.time['data'][index_at_start], 
                                  radar.time['units'])

#make a nice time stamp
pacific = pytz.timezone('US/Eastern')
local_time = pacific.fromutc(time_at_start_of_radar)
fancy_date_string = local_time.strftime('%A %B %d at %I:%M %p %Z')
print(fancy_date_string)
# Out:
# Wednesday May 30 at 01:59 PM EDT

# %%
# %matplotlib inline
#Set up our figure
fig = plt.figure(figsize = [10,7])

#create a Cartopy Py-ART display object
display = pyart.graph.RadarMapDisplayCartopy(radar)

#get center of the display for the projection
lat_0 = display.loc[0]
lon_0 = display.loc[1]

# Main difference from Basemap! 
#Cartopy forces you to select a projection first!
projection = cartopy.crs.Mercator(
                central_longitude=lon_0,
                min_latitude=35, max_latitude=45)

title = 'KIND \n' + fancy_date_string

#plot a PPI! add coastline at 10m resolution
display.plot_ppi_map(
    'reflectivity', sweep, colorbar_flag=True,
    title=title,
    projection=projection,
    min_lon=-88, max_lon=-84, min_lat=38, max_lat=41,
    vmin=-12, vmax=64, resolution='10m', 
    cmap=pyart.graph.cm.Wild25)

# Mark the radar
display.plot_point(lon_0, lat_0, label_text='KIND')

# Plot some lat and lon lines
gl = display.ax.gridlines(draw_labels=True,
                          linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
